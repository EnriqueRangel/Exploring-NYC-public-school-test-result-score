# %% [markdown]
# <a href="https://colab.research.google.com/github/EnriqueRangel/Exploring-NYC-public-school-test-result-score/blob/main/Exploring_NYC_public_school_test_result_score.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
schools = pd.read_csv("schools.csv")

# %%
schools.head(5)
# Out:
#    index                                        school_name    borough  \
# 0      0  New Explorations into Science, Technology and ...  Manhattan
# 1      1                               Essex Street Academy  Manhattan
# 2      2                       Lower Manhattan Arts Academy  Manhattan
# 3      3    High School for Dual Language and Asian Studies  Manhattan
# 4      4      Henry Street School for International Studies  Manhattan
#
#   building_code  average_math  average_reading  average_writing  \
# 0          M022           657              601              601
# 1          M445           395              411              387
# 2          M445           418              428              415
# 3          M445           613              453              463
# 4          M056           410              406              381
#
#    percent_tested
# 0             NaN
# 1            78.9
# 2            65.1
# 3            95.9
# 4            59.7

# %% [markdown]
# **Which NYC schools have the best math results?**

# %%
best_math_schools = schools[schools["average_math"] >= 640]

# %%
best_math_schools = best_math_schools.sort_values('average_math', ascending= False)

# %%
best_math_schools = best_math_schools[['school_name', 'average_math']]

# %%
best_math_schools.head(10)
# Out:
#                                            school_name  average_math
# 88                              Stuyvesant High School           754
# 170                       Bronx High School of Science           714
# 93                 Staten Island Technical High School           711
# 365  Queens High School for the Sciences at York Co...           701
# 68   High School for Mathematics, Science, and Engi...           683
# 280                     Brooklyn Technical High School           682
# 333                        Townsend Harris High School           680
# 174  High School of American Studies at Lehman College           669
# 0    New Explorations into Science, Technology and ...           657
# 45                       Eleanor Roosevelt High School           641

# %% [markdown]
# **What are the top 10 performing schools based on the combined SAT scores?**

# %%
#Make easy with a simple operation among Df
schools['total_SAT'] = schools['average_math'] + schools['average_reading'] + schools['average_writing']

# %%
#Ordenamiento en orden descendente:
schools = schools.sort_values('total_SAT', ascending= False)

# %%
#selecion de columna a visualizar
top_10_schools = schools[['school_name', 'total_SAT']]

# %%
#verificacion del top 10
top_10_schools = top_10_schools.head(10)

# %%
top_10_schools
# Out:
#                                            school_name  total_SAT
# 88                              Stuyvesant High School       2144
# 170                       Bronx High School of Science       2041
# 93                 Staten Island Technical High School       2041
# 174  High School of American Studies at Lehman College       2013
# 333                        Townsend Harris High School       1981
# 365  Queens High School for the Sciences at York Co...       1947
# 5                       Bard High School Early College       1914
# 280                     Brooklyn Technical High School       1896
# 45                       Eleanor Roosevelt High School       1889
# 68   High School for Mathematics, Science, and Engi...       1889

# %% [markdown]
# # Which single borough has the largest standard deviation in the combined SAT score?

# %%
schools.head(5)
# Out:
#      index                                        school_name        borough  \
# 88      88                             Stuyvesant High School      Manhattan
# 170    170                       Bronx High School of Science          Bronx
# 93      93                Staten Island Technical High School  Staten Island
# 174    174  High School of American Studies at Lehman College          Bronx
# 333    333                        Townsend Harris High School         Queens
#
#     building_code  average_math  average_reading  average_writing  \
# 88           M477           754              697              693
# 170          X445           714              660              667
# 93           R440           711              660              670
# 174          X905           669              672              672
# 333          Q515           680              640              661
#
#      percent_tested  total_SAT
# 88             97.4       2144
# 170            97.0       2041
# ...

# %%
borough_stats = schools.groupby('borough').agg(num_schools=('school_name', 'count'), average_SAT=('total_SAT', 'mean'), std_SAT=('total_SAT', 'std'))

# %%
borough_stats = borough_stats.round(2)

# %%
borough_stats = borough_stats.sort_values('std_SAT', ascending= False)

# %%
largest_std_dev = borough_stats.head(1)

# %%
largest_std_dev
# Out:
#            num_schools  average_SAT  std_SAT
# borough
# Manhattan           89      1340.13   230.29
